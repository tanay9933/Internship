# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
from selenium.webdriver.common.by import By
import time   # to create a delay

from bs4 import BeautifulSoup
import requests 
import warnings
warnings.filterwarnings ('ignore')

# %% [markdown]
# # Connecting to WEBDRIVER

# %%
driver = webdriver.Chrome(r'C:\Users\rjhcl\Desktop\web driver\chromedriver.exe')

# %% [markdown]
# # Opening Flipkart

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %% [markdown]
# # Writing on Search Option

# %%
input_ =driver.find_element(By.CLASS_NAME,"_3704LK")

input_.send_keys('smartphones')

# %% [markdown]
# # Clicking on Search Button

# %%
btn =driver.find_element(By.CLASS_NAME,"L0Z3Pu")
btn.click()

# %% [markdown]
# # Scraping Data

# %%
page_url = []
start=0 
end=2
for page in range(start, end):
    urls = driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
    for url in urls:
        page_url.append(url.get_attribute('href'))

# %%
len(page_url)
# Out:
# 48

# %%
url
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7a72fa669e1d3ef92dee8c7bdf42c512", element="20b62341-6ee2-4c8d-b0e5-4671b575c773")>

# %%
Smartphone_name  =[] 
Brand_Name =[] 
Price = []

colour =[]
Colour =[]

Details = []

# %%
for i in page_url:                  
    driver.get(i)        
    time.sleep(5) 

    
    try:
        Smartphone = driver.find_element(By.XPATH,'//div[@class="_4rR01T"]')
        
        Smartphone_name.append(Smartphone.text)
        
    except NoSuchElementException:
        Smartphone_name.append('NaN')
        
        
        
    
    try:
        Brand = driver.find_element(By.XPATH,'//div[@class="_4rR01T"]')
        
        Brand_Name.append(Brand.text(' ')[1])
        
    except NoSuchElementException:
        Brand_Name.append('NaN')
        
        
        
        
    
    try:
        amt = driver.find_element(By.XPATH,'//div[@class=""]')
        
        price.append(amt.text(' ')[1])
        
    except NoSuchElementException:
        price.append('NaN')
        
        
        
        
    try:
        color = driver.find_element(By.XPATH,'//div[@class="_4rR01T"]')
        for i in color:
            Color.append(i.text.split(', ')[0])        
            for i in Color:
                Colour.append(i.split(', ')[0])        
                
    except NoSuchElementException:
        Color.append('NaN')        
    
        
        
        
    
    try:
        det = driver.find_element(By.XPATH,'//li[@class="rgWa7D"]')
        
        details.append(det.text)
        
    except NoSuchElementException:
        details.append('NaN')

# %% [markdown]
# # Displaying Data

# %%
Smartphone_name
# Out:
# ['vivo T1 44W (Midnight Galaxy, 128 GB)',
#  'vivo T1 44W (Starry Sky, 128 GB)',
#  'MOTOROLA e40 (Carbon Gray, 64 GB)',
#  'POCO X4 Pro 5G (Laser Blue, 128 GB)',
#  'Infinix Smart 6 (Light Sea Green, 64 GB)',
#  'vivo T1 44W (Midnight Galaxy, 128 GB)',
#  'vivo T1 44W (Ice Dawn, 128 GB)',
#  'MOTOROLA G62 5G (Midnight Gray, 128 GB)',
#  'APPLE iPhone 14 (Starlight, 128 GB)',
#  'MOTOROLA g52 (Charcoal Grey, 128 GB)',
#  'REDMI 9i Sport (Metallic Blue, 64 GB)',
#  'Infinix Smart 6 (Heart Of Ocean, 64 GB)',
#  'Infinix Smart 6 (Starry Purple, 64 GB)',
#  'Infinix Smart 6 (Polar Black, 64 GB)',
#  'POCO C31 (Shadow Gray, 32 GB)',
#  'REDMI Note 11 SE (Cosmic White, 64 GB)',
#  'vivo T1 44W (Midnight Galaxy, 128 GB)',
#  'MOTOROLA G62 5G (Frosted Blue, 128 GB)',
#  'MOTOROLA G32 (Mineral Gray, 64 GB)',
#  'vivo T1 44W (Starry Sky, 128 GB)',
#  'POCO C31 (Shadow Gray, 64 GB)',
#  'MOTOROLA g42 (Atlantic Green, 64 GB)',
#  'REDMI 10 (Caribbean Green, 64 GB)',
# ...

# %%
Brand_Name
# Out:
# ['vivo',
#  'vivo',
#  'MOTOROLA',
#  'POCO',
#  'Infinix',
#  'vivo',
#  'vivo',
#  'MOTOROLA',
#  'APPLE',
#  'MOTOROLA',
#  'REDMI',
#  'Infinix',
#  'Infinix',
#  'Infinix',
#  'POCO',
#  'REDMI',
#  'vivo',
#  'MOTOROLA',
#  'MOTOROLA',
#  'vivo',
#  'POCO',
#  'MOTOROLA',
#  'REDMI',
#  'MOTOROLA',
#  'vivo',
#  'vivo',
#  'MOTOROLA',
#  'POCO',
#  'Infinix',
#  'vivo',
#  'vivo',
#  'MOTOROLA',
#  'APPLE',
#  'MOTOROLA',
#  'REDMI',
#  'Infinix',
#  'Infinix',
#  'Infinix',
#  'POCO',
#  'REDMI',
#  'vivo',
#  'MOTOROLA',
#  'MOTOROLA',
#  'vivo',
#  'POCO',
#  'MOTOROLA',
#  'REDMI',
#  'MOTOROLA',
#  'vivo',
#  'vivo',
#  'MOTOROLA',
#  'POCO',
#  'Infinix',
#  'vivo',
#  'vivo',
#  'MOTOROLA',
#  'APPLE',
#  'MOTOROLA',
#  'REDMI',
#  'Infinix',
#  'Infinix',
#  'Infinix',
#  'POCO',
#  'REDMI',
#  'vivo',
#  'MOTOROLA',
#  'MOTOROLA',
#  'vivo',
#  'POCO',
#  'MOTOROLA',
#  'REDMI',
#  'MOTOROLA',
#  'vivo',
#  'vivo',
#  'MOTOROLA',
#  'POCO',
#  'Infinix',
#  'vivo',
# ...

# %%
Price
# Out:
# ['₹14,499',
#  '₹14,499',
#  '₹8,299',
#  '₹16,499',
#  '₹6,499',
#  '₹15,999',
#  '₹14,499',
#  '₹14,999',
#  '₹72,499',
#  '₹12,999',
#  '₹7,499',
#  '₹6,499',
#  '₹6,499',
#  '₹6,499',
#  '₹6,499',
#  '₹11,999',
#  '₹17,999',
#  '₹15,999',
#  '₹10,499',
#  '₹15,999',
#  '₹7,749',
#  '₹10,999',
#  '₹9,999',
#  '₹14,999',
#  '₹14,499',
#  '₹14,499',
#  '₹8,299',
#  '₹16,499',
#  '₹6,499',
#  '₹15,999',
#  '₹14,499',
#  '₹14,999',
#  '₹72,499',
#  '₹12,999',
#  '₹7,499',
#  '₹6,499',
#  '₹6,499',
#  '₹6,499',
#  '₹6,499',
#  '₹11,999',
#  '₹17,999',
#  '₹15,999',
#  '₹10,499',
#  '₹15,999',
#  '₹7,749',
#  '₹10,999',
#  '₹9,999',
#  '₹14,999',
#  '₹14,499',
#  '₹14,499',
#  '₹8,299',
#  '₹16,499',
#  '₹6,499',
#  '₹15,999',
#  '₹14,499',
#  '₹14,999',
#  '₹72,499',
#  '₹12,999',
#  '₹7,499',
#  '₹6,499',
#  '₹6,499',
#  '₹6,499',
#  '₹6,499',
#  '₹11,999',
#  '₹17,999',
#  '₹15,999',
#  '₹10,499',
#  '₹15,999',
#  '₹7,749',
#  '₹10,999',
#  '₹9,999',
#  '₹14,999',
#  '₹14,499',
# ...

# %%
Colour
# Out:
# ['Midnight Galaxy',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Light Sea Green',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Light Sea Green',
#  'Midnight Galaxy',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Light Sea Green',
#  'Midnight Galaxy',
#  'Ice Dawn',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Light Sea Green',
#  'Midnight Galaxy',
#  'Ice Dawn',
#  'Midnight Gray',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Light Sea Green',
#  'Midnight Galaxy',
#  'Ice Dawn',
#  'Midnight Gray',
#  'Starlight',
#  'Midnight Galaxy',
#  'Starry Sky',
#  'Carbon Gray',
#  'Laser Blue',
#  'Light Sea Green',
#  'Midnight Galaxy',
#  'Ice Dawn',
# ...

# %%
Details
# Out:
# ['4 GB RAM | 128 GB ROM | Expandable Upto 1 TB',
#  '16.36 cm (6.44 inch) Full HD+ AMOLED Display',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '5000 mAh Lithium Battery',
#  'Qualcomm Snapdragon 680 Processor',
#  '1 Year Handset and 6 Months Accessories',
#  '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB',
#  '16.36 cm (6.44 inch) Full HD+ AMOLED Display',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '5000 mAh Lithium Battery',
#  'Qualcomm Snapdragon 680 Processor',
#  '1 Year Handset and 6 Months Accessories',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB',
#  '16.51 cm (6.5 inch) HD+ Display',
#  '48MP + 2MP + 2MP | 8MP Front Camera',
#  '5000 mAh Battery',
#  'UNISOC T700 Processor',
#  '1 Year on Handset and 6 Months on Accessories',
#  '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB',
#  '16.94 cm (6.67 inch) Full HD+ Super AMOLED Display',
#  '64MP + 8MP + 2MP | 16MP Front Camera',
#  '5000 mAh Lithium-ion Polymer Battery',
#  'Qualcomm Snapdragon 695 5G Processor',
# ...

# %% [markdown]
# # Checking Length

# %%
print(len(Smartphone_name), len(Brand_Name), len(Price), len(Details))
# Out:
# 240 240 240 1430

# %% [markdown]
# # Convert to Dataframe

# %%
#df=pd.DataFrame({'Smartphone':Smartphone_name, 'Brand':Brand_Name, 'Price':Price, 'Details': Details})

df=pd.DataFrame({'Smartphone':Smartphone_name, 'Brand':Brand_Name, 'Price':Price})

df
# Out:
#                                    Smartphone     Brand    Price
# 0       vivo T1 44W (Midnight Galaxy, 128 GB)      vivo  ₹14,499
# 1            vivo T1 44W (Starry Sky, 128 GB)      vivo  ₹14,499
# 2           MOTOROLA e40 (Carbon Gray, 64 GB)  MOTOROLA   ₹8,299
# 3         POCO X4 Pro 5G (Laser Blue, 128 GB)      POCO  ₹16,499
# 4    Infinix Smart 6 (Light Sea Green, 64 GB)   Infinix   ₹6,499
# ..                                        ...       ...      ...
# 235          vivo T1 44W (Starry Sky, 128 GB)      vivo  ₹15,999
# 236             POCO C31 (Shadow Gray, 64 GB)      POCO   ₹7,749
# 237      MOTOROLA g42 (Atlantic Green, 64 GB)  MOTOROLA  ₹10,999
# 238         REDMI 10 (Caribbean Green, 64 GB)     REDMI   ₹9,999
# 239    MOTOROLA G62 5G (Frosted Blue, 128 GB)  MOTOROLA  ₹14,999
#
# [240 rows x 3 columns]

# %% [markdown]
# # Save as Dataset

# %%
df.to_csv('FLIPKART.csv')
